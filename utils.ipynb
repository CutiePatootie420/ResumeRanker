# %%
from os.path import split
from pathlib import Path
BASE_DIR=Path.cwd()
PDF_DIR=BASE_DIR/"resume_folder"

# %%
import fitz
sample_2=fitz.open(PDF_DIR/"2.pdf")

# %%
for page in sample_2:
    blocks=page.get_text("blocks")
    for block in blocks:
        print(block)
        print("")
# Out:
# (35.775001525878906, 39.780029296875, 579.2360229492188, 68.780029296875, 'Deep M. Mehta | Full Stack Software Developer \n \n      \n deepmehta.co.in \nmail@deepmehta.co.in | github.com/deep-mm | linkedin.com/in/deepmehta97  \n \n \n      Redmond, WA \n', 0, 0)
#
# (35.775001525878906, 81.030029296875, 573.2360229492188, 120.79998779296875, 'EDUCATION \nNorth Carolina State University, Raleigh, NC \nMaster of Computer Science, Aug 2022 - May 2024 \n \n \n \n \n       GPA: 4.0/4.0 \n', 1, 0)
#
# (35.775001525878906, 128.79998779296875, 578.7360229492188, 153.29998779296875, 'K J Somaiya College of Engineering, Mumbai, India \nBachelor of Technology in Computer Engineering, Aug 2015 - May 2019  \n \n \n \n       GPA: 9.1/10.0 \n', 2, 0)
#
# (35.775001525878906, 165.54998779296875, 504.9360046386719, 258.58001708984375, 'SKILLS \nLanguages: \nC#, Java, Python, Ruby, Javascript, SQL \nWeb & Mobile: \nAngular, React, Android (XML, Java), React-Native, Ruby on Rails, Django \nCloud: \n Azure, AWS, Firebase \nAzure: \nApp-Service, Functions, AD, KeyVault, APIM, SQL, CosmosDB, Queue, Redis, IoT-\nHub, App-Gateway, Load-Balancer, VNet, VPN, Storage, Cognitive-Services, FHIR \nDevOps: \nAzure-DevOps, GitHub Actions, Terraform, ARM-Templates, Ansible, Kubernetes \n', 3, 0)
#
# (28.774999618530273, 270.8499755859375, 571.2059936523438, 324.3500061035156, 'WORK EXPERIENCE \nSoftware Engineer, Microsoft, Redmond, WA \n \n \n        June 2024 - Present \n• \nExperiences + Devices organization \n \n', 4, 0)
#
# (28.774999618530273, 328.6000061035156, 577.9860229492188, 394.8699951171875, 'Software Development Engineer Intern, Amazon, Seattle, WA \n \n \n        May 2023 - Aug 2023 \n• \nFull stack software development – Mobile App (React Native), Backend APIs (Java), Cloud (AWS) \n• \nIntegrated AWS Textract-powered OCR feature into mobile app, reducing manual effort for 50K+ monthly active \nusers by 85% and enhancing operational efficiency \n \n', 5, 0)
#
# (35.775001525878906, 397.3699951171875, 578.9860229492188, 562.6699829101562, 'Technology Consultant, Microsoft, Hyderabad, India \n \n \n             Jul 2019 – Jul 2022 \n• \nFull stack software development – Web Apps (Angular, React), Backend APIs (C#, Java), Cloud (Azure) \n• \nIoT – Healthcare customer, utilized Azure FHIR, IoT Hub, Functions, App Service to develop a fully functional IoT \nbased platform for researchers to collect and analyze data from participant Fitbit devices \n• \nCloud Governance – Banking customer, secured their cloud infrastructure with Azure Policy. Led a team for 18 \nmonths and my efforts were recognized in the form of Spark award for a successful delivery \n• \nDevOps – Automation pipelines with Azure-DevOps and GitHub Actions. Continuous Integration, Deployment, \nQuality, Security and Operations. Developed IPs, hosted masterclasses to educate and sell to customers \n• \nInfrastructure – Infrastructure as code with ARM-Templates and Terraform to deploy resources to cloud \n• \nScripting – Extensive scripting with Ansible, PowerShell and Unix Shell to automate configurations \n• \nCertifications – Azure Solutions Architect, Azure DevOps Engineer, Kubernetes Certified Application Developer \n• \nAwards – Best Consultant 2021, Spark Award 2021, Super Rookie 2020 \n', 6, 0)
#
# (35.775001525878906, 574.6799926757812, 529.4439697265625, 627.4500122070312, 'PROJECTS \nGenerative AI: Designed and implemented an innovative GitHub bot, harnessing the capabilities of advanced \nLanguage Models (LLMs), to automate the generation of Continuous Integration (CI) workflows within GitHub, \nenhancing efficiency and productivity. [github.com/apps/devops-llm-bot] \n', 7, 0)
#
# (35.775001525878906, 635.9500122070312, 562.4439697265625, 673.97998046875, "Azure Cloud Solution: Engineered an ultra-secure password management solution leveraging Azure's cutting-edge \nsecurity and networking capabilities, incorporating Azure AD, Azure KeyVault, Azure VNet, and Azure APIM, to ensure \ntop-notch data protection and access control. \n", 8, 0)
#
# (35.775001525878906, 682.469970703125, 550.0199584960938, 706.9749755859375, "DevOps: Created an IP solution bridging Azure DevOps' library group features with GitHub Actions, widely adopted \nacross large Microsoft projects, and available on GitHub Marketplace as an open-source tool. \n", 9, 0)
#
# (35.775001525878906, 715.4749755859375, 577.2360229492188, 739.9749755859375, 'Mobile App: Won first prize in an app development marathon for Oncue, a groundbreaking Android reminder app that \nutilizes Bluetooth to trigger reminders based on vicinity of a person, amassing over 500 downloads on Google Play Store. \n', 10, 0)

# %%
import  re
def extract_blocks(pdf_path):
    blocks=[]
    doc=fitz.open(pdf_path)
    for page in doc:
        temp=page.get_text("blocks")
        temp.sort(key=lambda x: (x[1],x[0]))
        blocks.extend(temp)
    return blocks
def clean_text(text):
    text=" ".join(text.split())
    text = re.sub(r"[^\w\s#+.]", " ", text)
    return text.lower()
def split_columns(blocks,threshold=300):
    left=[]
    right=[]
    for b in blocks:
        if b[0]<threshold:
            left.append(b)
        else:
            right.append(b)
    left.sort(key=lambda x: x[1])
    right.sort(key=lambda x: x[1])
    return left+right
def extract_sections(blocks):
    sections={"skills":[],"experience":[],"education":[],"projects":[]}
    current=None
    for b in blocks:
        text=clean_text(b[4])
        if not text:
            continue
        if "skill" in text:
            current="skills"
            continue
        elif "education" in text:
            current="education"
            continue
        elif "experience" in text:
            current="experience"
            continue
        elif "project" in text:
            current="projects"
            continue
        if current:
            sections[current].append(text)
    return sections
def extract_skills(text):
    text=" ".join(text)
    tokens = re.split(r"[,\n/]", text)
    skills = []
    for t in tokens:
        t = t.strip()
        if len(t) > 1:
            skills.append(t)
    return list(set(skills))
def parse_resume(path):
    blocks=extract_blocks(path)
    blocks=split_columns(blocks)
    sections=extract_sections(blocks)
    return {
        "skills": extract_skills(sections["skills"]),
        "experience": " ".join(sections["experience"]),
        "education": " ".join(sections["education"]),
        "projects": " ".join(sections["projects"]),
    }

# %%
sample_2=parse_resume(PDF_DIR/"2.pdf")
sample_2
# Out:
# {'skills': [],
#  'experience': 'software development engineer intern  amazon  seattle  wa may 2023   aug 2023   full stack software development   mobile app  react native   backend apis  java   cloud  aws    integrated aws textract powered ocr feature into mobile app  reducing manual effort for 50k+ monthly active users by 85  and enhancing operational efficiency technology consultant  microsoft  hyderabad  india jul 2019   jul 2022   full stack software development   web apps  angular  react   backend apis  c#  java   cloud  azure    iot   healthcare customer  utilized azure fhir  iot hub  functions  app service to develop a fully functional iot based platform for researchers to collect and analyze data from participant fitbit devices   cloud governance   banking customer  secured their cloud infrastructure with azure policy. led a team for 18 months and my efforts were recognized in the form of spark award for a successful delivery   devops   automation pipelines with azure devops and github actions. continuous integration  deployment  quality  security and operations. developed ips  hosted masterclasses to educate and sell to customers   infrastructure   infrastructure as code with arm templates and terraform to deploy resources to cloud   scripting   extensive scripting with ansible  powershell and unix shell to automate configurations   certifications   azure solutions architect  azure devops engineer  kubernetes certified application developer   awards   best consultant 2021  spark award 2021  super rookie 2020',
#  'education': 'k j somaiya college of engineering  mumbai  india bachelor of technology in computer engineering  aug 2015   may 2019 gpa  9.1 10.0',
#  'projects': 'azure cloud solution  engineered an ultra secure password management solution leveraging azure s cutting edge security and networking capabilities  incorporating azure ad  azure keyvault  azure vnet  and azure apim  to ensure top notch data protection and access control. mobile app  won first prize in an app development marathon for oncue  a groundbreaking android reminder app that utilizes bluetooth to trigger reminders based on vicinity of a person  amassing over 500 downloads on google play store.'}
