# %%
from google import genai
from dotenv import load_dotenv
import os
load_dotenv(override=True)
# Out:
# True

# %%
client=genai.Client(vertexai=True,api_key=os.getenv("gemapikey"))
model = "gemini-2.5-flash-lite"

# %%
response=client.models.generate_content(model=model,contents=["Say hello in one sentence"])

# %%
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   avg_logprobs=-0.13036581873893738,
#   content=Content(
#     parts=[
#       Part(
#         text='Hello!'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>
# )] create_time=datetime.datetime(2026, 3, 31, 15, 29, 17, 938560, tzinfo=TzInfo(0)) model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='TejLacCkOdHwqsMPxamXwAs' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=2,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=2
#     ),
#   ],
#   prompt_token_count=5,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=5
#     ),
#   ],
#   total_token_count=7,
#   traffic_type=<TrafficType.ON_DEMAND: 'ON_DEMAND'>
# ...

# %%
print(response.text)
# Out:
# Hello!
